# %% [markdown]
# # Plot the Group-Level Canonical Networks

# %%
from modules import hmm

n_states = 8
parcellation = "52ROI_Glasser"
plots_dir = f"plots/{n_states}_states_{parcellation}"

hmm.plot_canonical_group_level_networks(n_states=n_states, parcellation=parcellation, plots_dir=plots_dir)
hmm.display_network_plots(n_states=n_states, plots_dir=plots_dir)
# Out:
# 2025-11-11 18:47:32.726880: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-11 18:47:44 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_52ROI_Glasser/psd_00.png
# 2025-11-11 18:47:44 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_52ROI_Glasser/psd_01.png
# 2025-11-11 18:47:45 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_52ROI_Glasser/psd_02.png
# 2025-11-11 18:47:45 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_52ROI_Glasser/psd_03.png
# 2025-11-11 18:47:45 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_52ROI_Glasser/psd_04.png
# 2025-11-11 18:47:45 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_52ROI_Glasser/psd_05.png
# 2025-11-11 18:47:45 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_52ROI_Glasser/psd_06.png
# 2025-11-11 18:47:46 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_52ROI_Glasser/psd_07.png
# Saving images:   0%|          | 0/8 [00:00<?, ?it/s]
# Saving images:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
parcellation = "38ROI_Giles"
plots_dir = f"plots/{n_states}_states_{parcellation}"

hmm.plot_canonical_group_level_networks(n_states=n_states, parcellation=parcellation, plots_dir=plots_dir)
hmm.display_network_plots(n_states=n_states, plots_dir=plots_dir)
# Out:
# 2025-11-11 18:49:05 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_38ROI_Giles/psd_00.png
# 2025-11-11 18:49:05 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_38ROI_Giles/psd_01.png
# 2025-11-11 18:49:06 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_38ROI_Giles/psd_02.png
# 2025-11-11 18:49:06 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_38ROI_Giles/psd_03.png
# 2025-11-11 18:49:06 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_38ROI_Giles/psd_04.png
# 2025-11-11 18:49:06 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_38ROI_Giles/psd_05.png
# 2025-11-11 18:49:06 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_38ROI_Giles/psd_06.png
# 2025-11-11 18:49:07 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_38ROI_Giles/psd_07.png
# Saving images:   0%|          | 0/8 [00:00<?, ?it/s]
# Saving images:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
parcellation = "Elekta"
plots_dir = f"plots/{n_states}_states_{parcellation}"

hmm.plot_canonical_group_level_networks(n_states=n_states, parcellation=parcellation, plots_dir=plots_dir)
hmm.display_network_plots(n_states=n_states, plots_dir=plots_dir)
# Out:
# 2025-11-11 18:50:27 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/psd_00.png
# 2025-11-11 18:50:27 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/psd_01.png
# 2025-11-11 18:50:28 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/psd_02.png
# 2025-11-11 18:50:28 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/psd_03.png
# 2025-11-11 18:50:28 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/psd_04.png
# 2025-11-11 18:50:28 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/psd_05.png
# 2025-11-11 18:50:29 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/psd_06.png
# 2025-11-11 18:50:29 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/psd_07.png
# 2025-11-11 18:50:29 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/pow_00.png
# 2025-11-11 18:50:30 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/pow_01.png
# 2025-11-11 18:50:31 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/pow_02.png
# 2025-11-11 18:50:32 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/pow_03.png
# 2025-11-11 18:50:33 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/pow_04.png
# 2025-11-11 18:50:33 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/pow_05.png
# 2025-11-11 18:50:34 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/pow_06.png
# 2025-11-11 18:50:35 INFO osl-dynamics [plotting.py:107:save]: Saving plots/8_states_Elekta/pow_07.png
